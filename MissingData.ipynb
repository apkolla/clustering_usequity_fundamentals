# %% [markdown]
# <a href="https://colab.research.google.com/github/apkolla/clustering_usequity_fundamentals/blob/main/MissingData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
import requests
import time
import bs4 as bs
import datetime as dt
import io
import numpy as np
import time

# %%
df = pd.read_csv('fundamentals.csv')
df.drop(df.iloc[:, 0:1], inplace=True, axis=1)

# %%
print(df.shape)
print(df.dtypes)
print(df.isnull().sum())
# Out:
# (500, 31)
# Symbol                         object
# MarketCapitalization            int64
# EBITDA                         object
# PERatio                        object
# PEGRatio                       object
# BookValue                      object
# DividendPerShare               object
# DividendYield                  object
# EPS                           float64
# GrossProfitTTM                  int64
# DilutedEPSTTM                 float64
# QuarterlyEarningsGrowthYOY    float64
# QuarterlyRevenueGrowthYOY     float64
# TrailingPE                     object
# Beta                           object
# fiscalDateEnding               object
# grossProfit                    object
# totalRevenue                   object
# costOfRevenue                  object
# operatingIncome                 int64
# operatingExpenses              object
# ebit                           object
# netIncome                       int64
# totalAssets                     int64
# totalLiabilities                int64
# currentDebt                    object
# totalShareholderEquity          int64
# operatingCashflow              object
# capitalExpenditures            object
# profitLoss                     object
# dividendPayout                 object
# dtype: object
# Symbol                        0
# MarketCapitalization          0
# EBITDA                        0
# PERatio                       0
# PEGRatio                      0
# BookValue                     0
# DividendPerShare              0
# DividendYield                 0
# EPS                           0
# GrossProfitTTM                0
# DilutedEPSTTM                 0
# QuarterlyEarningsGrowthYOY    0
# QuarterlyRevenueGrowthYOY     0
# TrailingPE                    0
# Beta                          0
# fiscalDateEnding              0
# grossProfit                   0
# totalRevenue                  0
# costOfRevenue                 0
# operatingIncome               0
# operatingExpenses             0
# ebit                          0
# netIncome                     0
# totalAssets                   0
# totalLiabilities              0
# currentDebt                   0
# totalShareholderEquity        0
# operatingCashflow             0
# capitalExpenditures           0
# profitLoss                    0
# dividendPayout                0
# dtype: int64

# %% [markdown]
# Every feature should have imported as an integer or a float at the very least. Given there are no missing values, I am guessing the features imported with some other string. So lets take a look.

# %%
df.head()
# Out:
#   Symbol  MarketCapitalization       EBITDA PERatio PEGRatio BookValue  \
# 0    MMM           51511656000  -6610999808    None    4.153       8.7
# 1    AOS           11934819000    835700000   21.83    1.984     12.34
# 2    ABT          195185590000   9933000000    34.3    26.92     21.59
# 3   ABBV          308598571000  26254332000      64    1.622      6.85
# 4    ACN          233034121000  11303738000   34.48    2.508     42.55
#
#   DividendPerShare DividendYield    EPS  GrossProfitTTM  ...         ebit  \
# 0                6         0.065 -12.63     15000000000  ...  -8744000000
# 1             1.22        0.0159   3.69      1329600000  ...    233100000
# 2             2.08        0.0197   3.26     24579000000  ...   8864000000
# 3             5.99        0.0356   2.72     41527000000  ...  15698000000
# 4             4.82        0.0139  10.78     20731607000  ...   9054884000
#
#      netIncome   totalAssets totalLiabilities currentDebt  \
# 0  -6995000000   50580000000      45712000000  2947000000
# 1    235700000    3332300000       1584600000    10000000
# 2   6933000000   74438000000      37752000000  2251000000
# 3  11836000000  138805000000     121551000000  4136000000
# 4   6871557000   51245305000      25552466000   104810000
#
#   totalShareholderEquity operatingCashflow capitalExpenditures   profitLoss  \
# 0             4807000000        6680000000          1615000000  -6979000000
# 1             1747700000         391400000            70300000    235700000
# 2            36686000000        9581000000          1777000000  15239000000
# 3            17254000000       24943000000           695000000  11845000000
# 4            25692839000        9524268000           528172000  16142862000
#
#    dividendPayout
# 0      3311000000
# 1       177200000
# 2      3309000000
# 3     10043000000
# 4      2827394000
#
# [5 rows x 31 columns]

# %% [markdown]
# It looks like we have 'None' instead of NaN values, which is making the columns string. So, lets remove those strings and replace them with NaN. Then I will create a dataframe of the missing features and their value counts. From there I will write a function to loop through the original dataframe and collect the Symbol in a dictionary for each of the missing features.

# %%
df = df.replace('None',np.nan)
na_features = df.isna().sum()
cols = ['feature','na_count']
m_feats = pd.DataFrame(na_features).reset_index()
m_feats.columns = cols
missing = m_feats[m_feats['na_count']>0]
missing.sort_values(by='na_count',ascending=False).head(20)
# Out:
#                 feature  na_count
# 7         DividendYield        97
# 6      DividendPerShare        97
# 25          currentDebt        95
# 30       dividendPayout        81
# 3               PERatio        30
# 2                EBITDA        28
# 28  capitalExpenditures        12
# 4              PEGRatio         5
# 14                 Beta         3
# 29           profitLoss         3
# 21                 ebit         2
# 16          grossProfit         1
# 5             BookValue         1
# 18        costOfRevenue         1
# 20    operatingExpenses         1
# 27    operatingCashflow         1
# 17         totalRevenue         1

# %% [markdown]
# There are 17 features with missing values to varying degrees. Some of these will be easier to deal with than others. Lets start by looking at the dividend payout to get an idea of which companies even pay dividends

# %%
missing_divs = df.loc[df['DividendPerShare'].isna(),'Symbol'].tolist()

# %%
import yfinance as yf

# %%
div = {}
for ticker in missing_divs:
    ticker_object = yf.Ticker(ticker)
    if  ticker_object.dividends.empty:
      continue
    else:
      ticker_div = ticker_object.dividends[::-1][0]
      div[ticker]= ticker_div

# %%
dps = pd.DataFrame.from_dict(div,orient='index', columns=['DividendPerShare']).reset_index()
dps.columns = ['Symbol','DividendPerShare']
dps.head()
# Out:
#   Symbol  DividendPerShare
# 0   ADBE            0.0065
# 1    AAL            0.1000
# 2   APTV            0.2200
# 3   ADSK            0.0150
# 4     BA            2.0550

# %%
df = df.merge(dps,how='left', left_on = 'Symbol', right_on = 'Symbol')
df.columns
# Out:
# Index(['Symbol', 'MarketCapitalization', 'EBITDA', 'PERatio', 'PEGRatio',
#        'BookValue', 'DividendPerShare_x', 'DividendYield', 'EPS',
#        'GrossProfitTTM', 'DilutedEPSTTM', 'QuarterlyEarningsGrowthYOY',
#        'QuarterlyRevenueGrowthYOY', 'TrailingPE', 'Beta', 'fiscalDateEnding',
#        'grossProfit', 'totalRevenue', 'costOfRevenue', 'operatingIncome',
#        'operatingExpenses', 'ebit', 'netIncome', 'totalAssets',
#        'totalLiabilities', 'currentDebt', 'totalShareholderEquity',
#        'operatingCashflow', 'capitalExpenditures', 'profitLoss',
#        'dividendPayout', 'DividendPerShare_y'],
#       dtype='object')

# %%
df['DividendPerShare'] = df['DividendPerShare_x'].fillna(df['DividendPerShare_y'])
df.DividendPerShare.isna().sum()
# Out:
# 75

# %% [markdown]
# I am left with 76 companies with no dividend per share information from either of the two sources. Spot checking a few, and trusting two sources of data, I can confidetially say that these companies do not pay dividends, and I will fill their values in with a 0.

# %%
df.DividendPerShare.fillna(0,inplace=True)
df = df.drop(['DividendPerShare_x','DividendPerShare_y'],axis=1)
df['DividendPerShare'] = df.DividendPerShare.astype(float)
df.DividendPerShare.describe()
# Out:
# count    500.000000
# mean       2.209233
# std        2.445051
# min        0.000000
# 25%        0.500000
# 50%        1.605000
# 75%        3.127500
# max       20.000000
# Name: DividendPerShare, dtype: float64

# %% [markdown]
# Now that I have DPS information for all stocks, I can go through and calculate the dividend yield for the companies who have missing values. To do this I will have to pull in a historical price point for the equities who are missing data, and I will pull in the closing price on the last trading day of 2023 which was 12/29

# %%
missing_dy_tickers =  df.loc[df['DividendYield'].isna(),'Symbol'].to_list()
hist = yf.download(missing_dy_tickers, start="2023-12-29", end="2023-12-30")
# Out:
# [*********************100%%**********************]  97 of 97 completed

# %%
history = hist.stack().reset_index().rename(index=str, columns={"level_1": "Ticker"}).sort_values(['Ticker','Date'])
history.reset_index()
history = history[['Ticker','Close']]
history.head()
# Out:
# Price Ticker       Close
# 0        AAL   13.740000
# 1       ABNB  136.139999
# 2       ACGL   74.269997
# 3       ADBE  596.599976
# 4       ADSK  243.479996

# %%
history = history.merge(df[['Symbol','DividendPerShare']],how='left',left_on='Ticker',right_on='Symbol')
history['DividendYield'] = history['Close']/history['DividendPerShare']
history = history.replace(np.inf,0)
history.head()
# Out:
#   Ticker       Close Symbol  DividendPerShare  DividendYield
# 0    AAL   13.740000    AAL            0.1000     137.399998
# 1   ABNB  136.139999   ABNB            0.0000       0.000000
# 2   ACGL   74.269997   ACGL            0.0000       0.000000
# 3   ADBE  596.599976   ADBE            0.0065   91784.611629
# 4   ADSK  243.479996   ADSK            0.0150   16231.999715

# %%
df = df.merge(history[['Ticker','DividendYield']],how='left', left_on = 'Symbol', right_on = 'Ticker')
df['DividendYield'] = df['DividendYield_x'].fillna(df['DividendYield_y'])
df = df.drop(['DividendYield_x','DividendYield_y','Ticker'],axis=1)

# %% [markdown]
# Now, I am going to deal with the PE Ratio and PEG Ratios. Financial literature (source) indicates that that PEG Ratio is a better unit of comparison across companies in different industries and different growth rates than the PE ratio. For this reason, I will simply drop the PE Ratio from the analysis and move forward with the PEG.

# %%
df = df.drop('PERatio',axis=1)

# %%
#fill get data for missing PEG
missing_PEG =  df.loc[df['PEGRatio'].isna(),'Symbol'].to_list()
PEG = {}
#tickers = yf.Tickers(missing_ebitda)
#ebitda_df = pd.DataFrame(columns = ['webiste','ebitda','Symbol'])
for ticker in missing_PEG:
  t = yf.Ticker(ticker)
  x = t.info
  y = pd.DataFrame(x)
  if 'pegRatio' not in y:
    continue
  else:
    #print(y.pegRatio)
    z = y.pegRatio.mean()
    PEG[ticker] = z


PEGR = pd.DataFrame.from_dict(PEG,orient='index', columns=['PEGRatio']).reset_index()
PEGR.columns = ['Symbol','PEGRatio']
df = df.merge(PEGR[['Symbol','PEGRatio']],how='left', left_on = 'Symbol', right_on = 'Symbol')
df['PEGRatio'] = df['PEGRatio_x'].fillna(df['PEGRatio_y'])
df = df.drop(['PEGRatio_x','PEGRatio_y'],axis=1)

# %%
missing_PEG =  df.loc[df['PEGRatio'].isna(),'Symbol'].to_list()
missing_PEG
# Out:
# ['VLTO']

# %% [markdown]
# I am still missing the PEG for VLTO. For this I will manually look up the value from schwab.com and fill it in

# %%
df['PEGRatio'] = df.PEGRatio.fillna(4.56)

# %% [markdown]
# Same Process for EBITDA

# %%
#fill get data for missing PEG
missing_EBITDA =  df.loc[df['EBITDA'].isna(),'Symbol'].to_list()
EBITDA = {}
#tickers = yf.Tickers(missing_ebitda)
#ebitda_df = pd.DataFrame(columns = ['webiste','ebitda','Symbol'])
for ticker in missing_PEG:
  t = yf.Ticker(ticker)
  x = t.info
  y = pd.DataFrame(x)
  if 'ebitda' not in y:
    continue
  else:
    #print(y.pegRatio)
    z = y.ebitda.mean()
    EBITDA[ticker] = z


EBITDA = pd.DataFrame.from_dict(EBITDA,orient='index', columns=['EBITDA']).reset_index()
EBITDA.columns = ['Symbol','EBITDA']
df = df.merge(EBITDA[['Symbol','EBITDA']],how='left', left_on = 'Symbol', right_on = 'Symbol')
df['EBITDA'] = df['EBITDA_x'].fillna(df['EBITDA_y'])
df = df.drop(['EBITDA_x','EBITDA_y'],axis=1)

# %%
missing_EBITDA =  df.loc[df['EBITDA'].isna(),'Symbol'].to_list()
missing_EBITDA
# Out:
# ['AXP',
#  'BAC',
#  'BK',
#  'BX',
#  'COF',
#  'SCHW',
#  'C',
#  'CFG',
#  'CMA',
#  'DFS',
#  'EG',
#  'FITB',
#  'GS',
#  'HBAN',
#  'JPM',
#  'KEY',
#  'MTB',
#  'MS',
#  'NTRS',
#  'PNC',
#  'RJF',
#  'RF',
#  'STT',
#  'SYF',
#  'TFC',
#  'USB',
#  'WFC',
#  'ZION']

# %% [markdown]
# It looks like the yfinance package was unable to find ebitda for these 28 companies as well. Given that it is missing from two different sources, I will proceed by just dropping this feature from the analysis.

# %%
df = df.drop('EBITDA',axis=1)

# %%
#same process for currentDebt
missing_debt =  df.loc[df['currentDebt'].isna(),'Symbol'].to_list()
debt = {}
#tickers = yf.Tickers(missing_ebitda)
#ebitda_df = pd.DataFrame(columns = ['webiste','ebitda','Symbol'])
for ticker in missing_debt:
  t = yf.Ticker(ticker)
  x = t.info
  y = pd.DataFrame(x)
  if 'totalDebt' not in y:
    continue
  else:
    #print(y.pegRatio)
    z = y.totalDebt.mean()
    debt[ticker] = z


debt = pd.DataFrame.from_dict(debt,orient='index', columns=['currentDebt']).reset_index()
debt.columns = ['Symbol','currentDebt']
df = df.merge(debt[['Symbol','currentDebt']],how='left', left_on = 'Symbol', right_on = 'Symbol')
df['currentDebt'] = df['currentDebt_x'].fillna(df['currentDebt_y'])
df = df.drop(['currentDebt_x','currentDebt_y'],axis=1)

# %%
missing_debt =  df.loc[df['currentDebt'].isna(),'Symbol'].to_list()
print(missing_debt)
# Out:
# ['INTU', 'MPWR']

# %%
#manually fill in currentDebt for INTU MPWR
df.loc[df['Symbol'] == 'INTU', 'currentDebt'] = 6430000000
df.loc[df['Symbol'] == 'MPWR', 'currentDebt'] = 5780000

# %%
#capital Expenditures is not in yfinance data so this column will now be dropped along with dividendPayout
df = df.drop(['capitalExpenditures','dividendPayout'],axis=1)

# %%
#now I am left with features where 1-3 values are missing. I will now go manually fill these out using Google and yfinance for the specific company, and i will drop any columns not available in yfiancne
df.loc[df['Symbol'] == 'VLTO', 'BookValue'] = 17.89
df['BookValue']=df.BookValue.astype(float)
#Beta
df.loc[df['Symbol'] == 'VLTO', 'Beta'] = 1.43
df.loc[df['Symbol'] == 'KVUE', 'Beta'] = 0.64
df.loc[df['Symbol'] == 'GEHC', 'Beta'] = 1.03
df['Beta']=df.Beta.astype(float)
#Gross Profit
df = df.drop(['grossProfit'],axis=1)
#total revenue
df.loc[df['Symbol'] == 'VFC', 'totalRevenue'] = 6140000000
df['totalRevenue']=df.totalRevenue.astype(float)

df = df.drop(['costOfRevenue'],axis=1)

#operatingExpenses
df.loc[df['Symbol'] == 'VFC', 'operatingExpenses'] = 10680000000
df['operatingExpenses']=df.operatingExpenses.astype(float)

df = df.drop(['ebit','operatingCashflow','profitLoss'],axis=1)

# %%
df.to_csv('final_data.csv')

# %%
df.isna().sum()
# Out:
# Symbol                        0
# MarketCapitalization          0
# BookValue                     0
# EPS                           0
# GrossProfitTTM                0
# DilutedEPSTTM                 0
# QuarterlyEarningsGrowthYOY    0
# QuarterlyRevenueGrowthYOY     0
# TrailingPE                    0
# Beta                          0
# fiscalDateEnding              0
# totalRevenue                  0
# operatingIncome               0
# operatingExpenses             0
# netIncome                     0
# totalAssets                   0
# totalLiabilities              0
# totalShareholderEquity        0
# DividendPerShare              0
# DividendYield                 0
# PEGRatio                      0
# currentDebt                   0
# dtype: int64

# %%
msft = yf.Ticker("VFC")

# get all stock info
msft.info
# Out:
# {'address1': '1551 Wewatta Street',
#  'city': 'Denver',
#  'state': 'CO',
#  'zip': '80202',
#  'country': 'United States',
#  'phone': '720 778 4000',
#  'website': 'https://www.vfc.com',
#  'industry': 'Apparel Manufacturing',
#  'industryKey': 'apparel-manufacturing',
#  'industryDisp': 'Apparel Manufacturing',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': 'V.F. Corporation, together with its subsidiaries, engages in the design, procurement, marketing, and distribution of branded lifestyle apparel, footwear, and related products for men, women, and children in the Americas, Europe, and the Asia-Pacific. It operates through three segments: Outdoor, Active, and Work. The company offers outdoor, merino wool and other natural fibers-based, lifestyle, and casual apparel; footwear; equipment; accessories; outdoor-inspired, performance-based, youth culture/action sports-inspired, streetwear, and protective work footwear; handbags, luggage, backpacks, and totes; and work and work-inspired lifestyle apparel and footwear. It provides its products under The North Face, Timberland, Smartwool, Icebreaker, Altra, Vans, Supreme, Kipling, Napapijri, Eastpak, JanSport, Dickies, and Timberland PRO brand names. The company sells its products primarily to specialty stores, department stores, national chains, and mass merchants, as well as sells through direct-to-consumer operations, including retail stores, concession retail stores, and e-commerce sites, and other digital platforms. V.F. Corporation was founded in 1899 and is headquartered in Denver, Colorado.',
#  'fullTimeEmployees': 19800,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Matthew H. Puckett',
#    'age': 48,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1975,
#    'fiscalYear': 2023,
#    'totalPay': 789214,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Martino Scabbia Guerrini',
#    'age': 59,
#    'title': 'Executive VP, Global Chief Commercial Officer & President of Emerging Brands',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 929828,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Nicole Beth Otto',
#    'age': 52,
#    'title': 'Global Brand President of The North Face',
#    'yearBorn': 1971,
#    'fiscalYear': 2023,
#    'totalPay': 920489,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bracken P. Darrell',
#    'age': 60,
#    'title': 'President, CEO & Director',
#    'yearBorn': 1963,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bryan H. McNeill',
#    'age': 61,
#    'title': 'VP, Controller & Chief Accounting Officer',
#    'yearBorn': 1962,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Velia  Carboni',
#    'age': 54,
#    'title': 'Executive VP and Chief Digital & Technology Officer',
#    'yearBorn': 1969,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Allegra  Perry',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jennifer S. Sim',
#    'age': 48,
#    'title': 'Executive VP, General Counsel & Secretary',
#    'yearBorn': 1975,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brian  Beckstead',
#    'title': 'Founder & Chief Marketing Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Brent  Hyder',
#    'age': 58,
#    'title': 'Chief People Officer',
#    'yearBorn': 1965,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 1,
#  'boardRisk': 1,
#  'compensationRisk': 8,
#  'shareHolderRightsRisk': 8,
#  'overallRisk': 4,
#  'governanceEpochDate': 1706745600,
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 15.9,
#  'open': 15.9,
#  'dayLow': 15.785,
#  'dayHigh': 16.14,
#  'regularMarketPreviousClose': 15.9,
#  'regularMarketOpen': 15.9,
#  'regularMarketDayLow': 15.785,
#  'regularMarketDayHigh': 16.14,
#  'dividendRate': 0.36,
#  'dividendYield': 0.0225,
#  'exDividendDate': 1709856000,
#  'payoutRatio': 5.3666997,
#  'fiveYearAvgDividendYield': 4.18,
#  'beta': 1.542,
#  'forwardPE': 11.75,
#  'volume': 5139879,
#  'regularMarketVolume': 5139879,
#  'averageVolume': 7843970,
#  'averageVolume10days': 8330420,
#  'averageDailyVolume10Day': 8330420,
#  'bid': 15.81,
#  'ask': 15.93,
#  'bidSize': 3200,
#  'askSize': 1400,
#  'marketCap': 6213279744,
#  'fiftyTwoWeekLow': 12.85,
#  'fiftyTwoWeekHigh': 26.95,
#  'priceToSalesTrailing12Months': 0.5742153,
#  'fiftyDayAverage': 17.184,
#  'twoHundredDayAverage': 18.0383,
#  'trailingAnnualDividendRate': 0.99,
#  'trailingAnnualDividendYield': 0.062264152,
#  'currency': 'USD',
#  'enterpriseValue': 12565419008,
#  'profitMargins': -0.07074,
#  'floatShares': 384822816,
#  'sharesOutstanding': 388816000,
#  'sharesShort': 29002132,
#  'sharesShortPriorMonth': 23746641,
#  'sharesShortPreviousMonthDate': 1703808000,
#  'dateShortInterest': 1706659200,
#  'sharesPercentSharesOut': 0.0746,
#  'heldPercentInsiders': 0.00937,
#  'heldPercentInstitutions': 0.88426,
#  'shortRatio': 4.34,
#  'shortPercentOfFloat': 0.083900005,
#  'impliedSharesOutstanding': 388816000,
#  'bookValue': 5.425,
#  'priceToBook': 2.945622,
#  'lastFiscalYearEnd': 1680307200,
#  'nextFiscalYearEnd': 1711929600,
#  'mostRecentQuarter': 1703894400,
#  'netIncomeToCommon': -765465984,
#  'trailingEps': -1.97,
#  'forwardEps': 1.36,
#  'pegRatio': 73.6,
#  'lastSplitFactor': '1062:1000',
#  'lastSplitDate': 1558569600,
#  'enterpriseToRevenue': 1.161,
#  'enterpriseToEbitda': 11.761,
#  '52WeekChange': -0.34292763,
#  'SandP52WeekChange': 0.27787375,
#  'lastDividendValue': 0.09,
#  'lastDividendDate': 1701993600,
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'VFC',
#  'underlyingSymbol': 'VFC',
#  'shortName': 'V.F. Corporation',
#  'longName': 'V.F. Corporation',
#  'firstTradeDateEpochUtc': 322151400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '4ed08eb7-9730-3e70-8326-3d82c893dbab',
#  'messageBoardId': 'finmb_191328',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 15.98,
#  'targetHighPrice': 23.0,
#  'targetLowPrice': 13.0,
#  'targetMeanPrice': 16.73,
#  'targetMedianPrice': 16.0,
#  'recommendationMean': 2.8,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 19,
#  'totalCash': 989742976,
#  'totalCashPerShare': 2.546,
#  'ebitda': 1068372992,
#  'totalDebt': 7341882880,
#  'quickRatio': 0.586,
#  'currentRatio': 1.235,
#  'totalRevenue': 10820470784,
#  'debtToEquity': 348.09,
#  'revenuePerShare': 27.871,
#  'returnOnAssets': 0.03562,
#  'returnOnEquity': -0.282,
#  'freeCashflow': 1006067648,
#  'operatingCashflow': 1283424000,
#  'revenueGrowth': -0.162,
#  'grossMargins': 0.52269,
#  'ebitdaMargins': 0.09874,
#  'operatingMargins': 0.09316,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 0.1725}
